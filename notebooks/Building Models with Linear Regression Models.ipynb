# %% [markdown]
# # 1. Installation of required libraries and Understanding the dataset

# %%
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Reading the dataset
hitters_data = pd.read_csv("../data/Hitters.csv")
df = hitters_data.copy()
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
# Quick facts
df.describe().T
# Out:
#          count         mean          std   min     25%     50%      75%  \
# AtBat    322.0   380.928571   153.404981  16.0  255.25   379.5   512.00
# Hits     322.0   101.024845    46.454741   1.0   64.00    96.0   137.00
# HmRun    322.0    10.770186     8.709037   0.0    4.00     8.0    16.00
# Runs     322.0    50.909938    26.024095   0.0   30.25    48.0    69.00
# RBI      322.0    48.027950    26.166895   0.0   28.00    44.0    64.75
# Walks    322.0    38.742236    21.639327   0.0   22.00    35.0    53.00
# Years    322.0     7.444099     4.926087   1.0    4.00     6.0    11.00
# CAtBat   322.0  2648.683230  2324.205870  19.0  816.75  1928.0  3924.25
# CHits    322.0   717.571429   654.472627   4.0  209.00   508.0  1059.25
# CHmRun   322.0    69.490683    86.266061   0.0   14.00    37.5    90.00
# CRuns    322.0   358.795031   334.105886   1.0  100.25   247.0   526.25
# CRBI     322.0   330.118012   333.219617   0.0   88.75   220.5   426.25
# CWalks   322.0   260.239130   267.058085   0.0   67.25   170.5   339.25
# PutOuts  322.0   288.937888   280.704614   0.0  109.25   212.0   325.00
# Assists  322.0   106.913043   136.854876   0.0    7.00    39.5   166.00
# Errors   322.0     8.040373     6.368359   0.0    3.00     6.0    11.00
# Salary   263.0   535.925882   451.118681  67.5  190.00   425.0   750.00
#
#              max
# AtBat      687.0
# Hits       238.0
# HmRun       40.0
# Runs       130.0
# RBI        121.0
# Walks      105.0
# Years       24.0
# CAtBat   14053.0
# CHits     4256.0
# CHmRun     548.0
# CRuns     2165.0
# CRBI      1659.0
# CWalks    1566.0
# PutOuts   1378.0
# Assists    492.0
# Errors      32.0
# Salary    2460.0

# %%
# Data size
df.shape
# Out:
# (322, 20)

# %%
# How many missing values ​​are there?
df.isnull().sum()
# Out:
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64

# %%
# Looking at missing data
df[df["Salary"].isnull()].head()
# Out:
#     AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0     293    66      1    30   29     14      1     293     66       1     30
# 15    183    39      3    20   15     11      3     201     42       3     20
# 18    407   104      6    57   43     65     12    5233   1478     100    643
# 22     22    10      1     4    2      1      6      84     26       2      9
# 30    313    84      9    42   30     39     17    6890   1833     224   1033
#
#     CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0     29      14      A        E      446       33      20     NaN         A
# 15    16      11      A        W      118        0       0     NaN         A
# 18   658     653      A        W      912       88       9     NaN         A
# 22     9       3      A        W      812       84      11     NaN         A
# 30   864    1087      A        W      127      221       7     NaN         A

# %% [markdown]
# # 2. Results obtained by deleting missing data and without performing any further analysis

# %% [markdown]
# ## 2.1.1 Simple linear regression with the entire dataset

# %%
# We delete missing data.
df.dropna(inplace = True)
df.shape
# Out:
# (263, 20)

# %%
# We choose to use only the CHits variable in the dataset.
X = df[["CHits"]]
y = df[["Salary"]]
X = scaler.fit_transform(X)
reg_model = LinearRegression()
reg_model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Formula: "+str(reg_model.intercept_)+" "+str(reg_model.coef_)+"x1")
# Out:
# Formula: [535.92588213] [[247.15214091]]x1

# %%
y_pred = reg_model.predict(X)

# %%
from sklearn.metrics import mean_squared_error
sonuc_tum_veri_slr = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_slr
# Out:
# 376.3643027728653

# %%
sonuc_tum_veri_cv_slr = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_slr
# Out:
# 383.4526516640398

# %% [markdown]
# ## 2.1.2 Simple linear regression separated into train and test

# %%
X = df[["CHits"]]
y = df[["Salary"]]
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Formula: "+str(reg_model.intercept_)+" "+str(reg_model.coef_)+"x1")
# Out:
# Formula: [537.78313303] [[270.03230409]]x1

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_slr = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_slr
# Out:
# 348.96784372179457

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_slr = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_slr
# Out:
# 472.230050228946

# %%
sonuc_tt_veri_cv_slr = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_slr
# Out:
# 352.69590920059227

# %% [markdown]
# # 2.2.1 Multiple linear regression with the entire dataset

# %%
# We express categorical variables as 1-0
df = pd.get_dummies(df, columns = ['League', 'Division', 'NewLeague'], drop_first = True)

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)
X = scaler.fit_transform(X)

# %%
reg_model = LinearRegression()
reg_model.fit(X, y)
# Out:
# LinearRegression()

# %%
print(reg_model.intercept_)
# Out:
# 535.9258821292775

# %%
print(reg_model.coef_)
# Out:
# [-291.0945557   337.83047948   37.85383676  -60.57247861  -26.99498379
#   135.07389695  -16.69335888 -391.03865466   86.68761664  -14.18172332
#   480.74713477  260.68988581 -213.89225864   78.76129639   53.73248973
#   -22.16086217   31.2487626   -58.41406355  -12.34881102]

# %%
y_pred = reg_model.predict(X)

# %%
sonuc_tum_veri_clr = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_clr
# Out:
# 303.34447253531613

# %%
sonuc_tum_veri_cv_clr = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_clr
# Out:
# 341.46597732981036

# %% [markdown]
# ## 2.2.2 Multiple linear regression separated into train and test

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(reg_model.intercept_)
# Out:
# 534.5934048105765

# %%
print(reg_model.coef_)
# Out:
# [-1.81989481e+02  2.33568966e+02  5.25917808e+01  2.07325675e+01
#  -3.46308954e+01  4.81565534e+01 -1.14645801e-01 -9.31358594e+02
#   1.11333493e+03  1.98450308e+02  1.27811909e+02 -2.35205399e+02
#  -1.84619883e+01  9.16202977e+01  2.31451518e+01 -4.36054446e+00
#   3.69787336e+01 -2.73605842e+01 -2.69655270e+01]

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_clr = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_clr
# Out:
# 261.36151857439336

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_clr = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_clr
# Out:
# 479.07150373702115

# %%
sonuc_tt_veri_cv_clr = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_clr
# Out:
# 307.225760590695

# %% [markdown]
# ## 2.3.1 Ridge Regression with all data

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)
X = scaler.fit_transform(X)

# %%
reg_model = Ridge()
reg_model.fit(X, y)
# Out:
# Ridge()

# %%
print(reg_model.intercept_)
# Out:
# 535.9258821292775

# %%
print(reg_model.coef_)
# Out:
# [-270.47549797  296.56190392   18.1638957   -29.40456794   -9.21637609
#   124.44029854  -38.69207918 -225.35662735  126.90023608   39.08043983
#   320.21040942  160.36986132 -184.49438733   78.60950469   47.44645692
#   -23.76376773   31.01887447  -60.24628766  -13.67402282]

# %%
y_pred = reg_model.predict(X)

# %%
sonuc_tum_veri_ridge = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_ridge
# Out:
# 304.1140381775486

# %%
sonuc_tum_veri_cv_ridge = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_ridge
# Out:
# 338.45318355057594

# %% [markdown]
# ## 2.3.2 Ridge Regression by separating train and test

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
reg_model = Ridge()
reg_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
print(reg_model.intercept_)
# Out:
# 534.3842751448135

# %%
print(reg_model.coef_)
# Out:
# [-2.12250580e+02  2.94521009e+02  5.61152622e+01 -2.55351846e+00
#  -4.37183213e+01  6.01153833e+01 -3.86917951e+01 -2.61823619e+02
#   2.83960961e+02  7.01505168e+01  2.64726580e+02 -1.60888933e+01
#  -8.13605795e+01  9.06581582e+01  8.41866713e+00  6.12518006e-02
#   3.19909624e+01 -3.13095890e+01 -2.03624248e+01]

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_ridge = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_ridge
# Out:
# 264.57675950942337

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_ridge = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_ridge
# Out:
# 458.75144252220116

# %%
sonuc_tt_veri_cv_ridge = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_ridge
# Out:
# 301.30845041111684

# %% [markdown]
# ## 2.4.1 Lasso Regression with the entire dataset

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)
X = scaler.fit_transform(X)

# %%
reg_model =Lasso()
reg_model.fit(X, y)
# Out:
# Lasso()

# %%
print(reg_model.intercept_)
# Out:
# 535.9258821292775

# %%
print(reg_model.coef_)
# Out:
# [-281.1172681   303.71277457   11.13050868  -25.23750713   -0.
#   120.83597005  -35.04328737 -161.32198712    0.           14.27182293
#   375.15175777  192.2154112  -190.2391271    78.6764498    41.88526703
#   -18.83445093   23.20900807  -58.23442843   -4.94183895]

# %%
y_pred = reg_model.predict(X)

# %%
sonuc_tum_veri_lasso = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_lasso
# Out:
# 304.3172941943879

# %%
sonuc_tum_veri_cv_lasso = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_lasso
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9820.372265029699, tolerance: 4637.712860074582
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16226.579207986593, tolerance: 4976.191260952606
#   positive)
# 338.62654726299627

# %% [markdown]
# ## 2.4.2 Lasso Regression by separating train and test

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
reg_model =Lasso()
reg_model.fit(X_train, y_train)
# Out:
# Lasso()

# %%
print(reg_model.intercept_)
# Out:
# 534.1205196004398

# %%
print(reg_model.coef_)
# Out:
# [-196.30842607  276.77508177   51.8781116     0.          -34.54898782
#    51.79290628  -24.37765742 -423.94957962  402.3140429    58.93022571
#   269.48957057   -0.          -57.578216     89.43835188    8.90737726
#     0.           25.73766269  -28.96185078  -14.25654751]

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_lasso = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_lasso
# Out:
# 263.7056447668435

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_lasso = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_lasso
# Out:
# 461.2422858691614

# %%
sonuc_tt_veri_cv_lasso = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_lasso
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16513.212395645678, tolerance: 3651.8483906293914
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7964.692977316678, tolerance: 3684.426158113166
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4623.670405648649, tolerance: 3724.140602819258
#   positive)
# 301.1205249294909

# %% [markdown]
# ## 2.5.1 ElasticNet Regression with the entire dataset

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)
X = scaler.fit_transform(X)

# %%
reg_model =ElasticNet()
reg_model.fit(X, y)
# Out:
# ElasticNet()

# %%
print(reg_model.intercept_)
# Out:
# 535.9258821292775

# %%
print(reg_model.coef_)
# Out:
# [  5.76548475  44.32773203   1.63340483  28.13065891  22.59245714
#   38.47123143   1.55719543  25.61720464  41.11724494  36.25263909
#   41.71364158  43.50751186   8.82399977  52.26616588   5.18046378
#  -10.83125396  12.90217625 -44.6639689    3.56603582]

# %%
y_pred = reg_model.predict(X)

# %%
sonuc_tum_veri_enet = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_enet
# Out:
# 326.5621957219224

# %%
sonuc_tum_veri_cv_enet = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_enet
# Out:
# 343.0594626712361

# %% [markdown]
# ## 2.5.2 ElasticNet Regression by separating train and test

# %%
y = df["Salary"]
X = df.drop('Salary', axis=1)
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
reg_model =ElasticNet()
reg_model.fit(X_train, y_train)
# Out:
# ElasticNet()

# %%
print(reg_model.intercept_)
# Out:
# 532.598622403121

# %%
print(reg_model.coef_)
# Out:
# [ 15.98081773  51.74110102  16.66354522  37.74294628  17.59195988
#   24.72879384   3.31024486  28.15263103  43.92408862  28.65612752
#   45.28632057  34.09192393  16.7331638   61.40582858  -7.70403344
#   -1.29334611  12.12353304 -28.22986528   0.75801616]

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_enet = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_enet
# Out:
# 285.63335637134685

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_enet = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_enet
# Out:
# 463.93529372031867

# %%
sonuc_tt_veri_cv_enet = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_enet
# Out:
# 299.84842837413936

# %%
# First results output
basicsonuc_df = pd.DataFrame({"All Data Error":[sonuc_tum_veri_slr,sonuc_tum_veri_clr,sonuc_tum_veri_ridge,sonuc_tum_veri_lasso,sonuc_tum_veri_enet],
                              "All Data cvScore(K-Fold)":[sonuc_tum_veri_cv_slr,sonuc_tum_veri_cv_clr,sonuc_tum_veri_cv_ridge,sonuc_tum_veri_cv_lasso,sonuc_tum_veri_cv_enet],
                              "Train Error":[sonuc_train_veri_slr,sonuc_train_veri_clr,sonuc_train_veri_ridge,sonuc_train_veri_lasso,sonuc_train_veri_enet],
                              "Test Error":[sonuc_test_veri_slr,sonuc_test_veri_clr,sonuc_test_veri_ridge,sonuc_test_veri_lasso,sonuc_test_veri_enet],                
                              "Train cvScore(K-Fold)":[sonuc_tt_veri_cv_slr,sonuc_tt_veri_cv_clr,sonuc_tt_veri_cv_ridge,sonuc_tt_veri_cv_lasso,sonuc_tt_veri_cv_enet]})
basicsonuc_df.index= ["SLR", "CLR","RID","LAS","ENE"]
basicsonuc_df
# Out:
#      All Data Error  All Data cvScore(K-Fold)  Train Error  Test Error  \
# SLR      376.364303                383.452652   348.967844  472.230050
# CLR      303.344473                341.465977   261.361519  479.071504
# RID      304.114038                338.453184   264.576760  458.751443
# LAS      304.317294                338.626547   263.705645  461.242286
# ENE      326.562196                343.059463   285.633356  463.935294
#
#      Train cvScore(K-Fold)
# SLR             352.695909
# CLR             307.225761
# RID             301.308450
# LAS             301.120525
# ENE             299.848428

# %% [markdown]
# # 3. Data Pre-processing steps (Missing data, outlier data analysis)

# %%
df = hitters_data.copy()
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %%
df.corr()
# Out:
#             AtBat      Hits     HmRun      Runs       RBI     Walks     Years  \
# AtBat    1.000000  0.967939  0.592198  0.913060  0.820539  0.669845  0.047372
# Hits     0.967939  1.000000  0.562158  0.922187  0.811073  0.641211  0.044767
# HmRun    0.592198  0.562158  1.000000  0.650988  0.855122  0.481014  0.116318
# Runs     0.913060  0.922187  0.650988  1.000000  0.798206  0.732213  0.004541
# RBI      0.820539  0.811073  0.855122  0.798206  1.000000  0.615997  0.146168
# Walks    0.669845  0.641211  0.481014  0.732213  0.615997  1.000000  0.136475
# Years    0.047372  0.044767  0.116318  0.004541  0.146168  0.136475  1.000000
# CAtBat   0.235526  0.227565  0.221882  0.186497  0.294688  0.277175  0.920289
# CHits    0.252717  0.255815  0.220627  0.204830  0.308201  0.280671  0.903631
# CHmRun   0.236659  0.202712  0.493227  0.227913  0.441771  0.332473  0.726872
# CRuns    0.266534  0.261787  0.262361  0.250556  0.323285  0.338478  0.882877
# CRBI     0.244053  0.232005  0.351979  0.205976  0.393184  0.308631  0.868812
# CWalks   0.166123  0.151818  0.233154  0.182168  0.250914  0.424507  0.838533
# PutOuts  0.317550  0.310673  0.282923  0.279347  0.343186  0.299515 -0.004684
# Assists  0.353824  0.320455 -0.106329  0.220567  0.106591  0.149656 -0.080638
# Errors   0.352117  0.310038  0.039318  0.240475  0.193370  0.129382 -0.162140
# Salary   0.394771  0.438675  0.343028  0.419859  0.449457  0.443867  0.400657
#
#            CAtBat     CHits    CHmRun     CRuns      CRBI    CWalks   PutOuts  \
# AtBat    0.235526  0.252717  0.236659  0.266534  0.244053  0.166123  0.317550
# Hits     0.227565  0.255815  0.202712  0.261787  0.232005  0.151818  0.310673
# HmRun    0.221882  0.220627  0.493227  0.262361  0.351979  0.233154  0.282923
# Runs     0.186497  0.204830  0.227913  0.250556  0.205976  0.182168  0.279347
# RBI      0.294688  0.308201  0.441771  0.323285  0.393184  0.250914  0.343186
# Walks    0.277175  0.280671  0.332473  0.338478  0.308631  0.424507  0.299515
# Years    0.920289  0.903631  0.726872  0.882877  0.868812  0.838533 -0.004684
# CAtBat   1.000000  0.995063  0.798836  0.983345  0.949219  0.906501  0.062283
# CHits    0.995063  1.000000  0.783306  0.984609  0.945141  0.890954  0.076547
# CHmRun   0.798836  0.783306  1.000000  0.820243  0.929484  0.799983  0.112724
# CRuns    0.983345  0.984609  0.820243  1.000000  0.943769  0.927807  0.064180
# CRBI     0.949219  0.945141  0.929484  0.943769  1.000000  0.884726  0.110098
# CWalks   0.906501  0.890954  0.799983  0.927807  0.884726  1.000000  0.058638
# PutOuts  0.062283  0.076547  0.112724  0.064180  0.110098  0.058638  1.000000
# Assists  0.002038 -0.002523 -0.158511 -0.022978 -0.079387 -0.039130 -0.025024
# Errors  -0.066922 -0.062756 -0.138115 -0.084395 -0.100990 -0.118475  0.109972
# Salary   0.526135  0.548910  0.524931  0.562678  0.566966  0.489822  0.300480
#
#           Assists    Errors    Salary
# AtBat    0.353824  0.352117  0.394771
# Hits     0.320455  0.310038  0.438675
# HmRun   -0.106329  0.039318  0.343028
# Runs     0.220567  0.240475  0.419859
# RBI      0.106591  0.193370  0.449457
# Walks    0.149656  0.129382  0.443867
# Years   -0.080638 -0.162140  0.400657
# CAtBat   0.002038 -0.066922  0.526135
# CHits   -0.002523 -0.062756  0.548910
# CHmRun  -0.158511 -0.138115  0.524931
# CRuns   -0.022978 -0.084395  0.562678
# CRBI    -0.079387 -0.100990  0.566966
# CWalks  -0.039130 -0.118475  0.489822
# PutOuts -0.025024  0.109972  0.300480
# Assists  1.000000  0.706362  0.025436
# Errors   0.706362  1.000000 -0.005401
# Salary   0.025436 -0.005401  1.000000

# %%
df[["CHits","Salary"]].describe([0.01,0.05,0.10,0.25,0.50,0.75,0.90,0.95, 0.99]).T
# Out:
#         count        mean         std   min     1%    5%    10%    25%    50%  \
# CHits   322.0  717.571429  654.472627   4.0   9.84  54.0   86.0  209.0  508.0
# Salary  263.0  535.925882  451.118681  67.5  70.00  86.6  100.0  190.0  425.0
#
#             75%        90%      95%         99%     max
# CHits   1059.25  1659.6000  2017.15  2500.34000  4256.0
# Salary   750.00  1048.6666  1346.00  2032.88654  2460.0

# %%
# Splitting variables into 4 parts
df["ChitsScore"] = pd.qcut(df['CHits'], 4, labels = [1,2,3,4])
df["SalaryScore"] = pd.qcut(df['Salary'], 4, labels = [1,2,3,4])
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  ...  \
# 0    293    66      1    30   29     14      1     293     66       1  ...
# 1    315    81      7    24   38     39     14    3449    835      69  ...
# 2    479   130     18    66   72     76      3    1624    457      63  ...
# 3    496   141     20    65   78     37     11    5628   1575     225  ...
# 4    321    87     10    39   42     30      2     396    101      12  ...
#
#    CWalks  League  Division PutOuts Assists  Errors  Salary  NewLeague  \
# 0      14       A         E     446      33      20     NaN          A
# 1     375       N         W     632      43      10   475.0          N
# 2     263       A         W     880      82      14   480.0          A
# 3     354       N         E     200      11       3   500.0          N
# 4      33       N         E     805      40       4    91.5          N
#
#    ChitsScore SalaryScore
# 0           1         NaN
# 1           3           3
# 2           2           3
# 3           4           3
# 4           1           1
#
# [5 rows x 22 columns]

# %%
# Assign the median of the equal parts in the 4 parts to the missing value
for i in df[df["Salary"].isnull()].index:
    if df.loc[i,"ChitsScore"] == 1:
        df.loc[i,"Salary"] = df[df["ChitsScore"]==1]["Salary"].median()
    elif df.loc[i,"ChitsScore"] == 2:
        df.loc[i,"Salary"] = df[df["ChitsScore"]==2]["Salary"].median()
    elif df.loc[i,"ChitsScore"] == 3:
        df.loc[i,"Salary"] = df[df["ChitsScore"]==3]["Salary"].median()
    else:
        df.loc[i,"Salary"] = df[df["ChitsScore"]==4]["Salary"].median()

# %%
df.isnull().sum()
# Out:
# AtBat           0
# Hits            0
# HmRun           0
# Runs            0
# RBI             0
# Walks           0
# Years           0
# CAtBat          0
# CHits           0
# CHmRun          0
# CRuns           0
# CRBI            0
# CWalks          0
# League          0
# Division        0
# PutOuts         0
# Assists         0
# Errors          0
# Salary          0
# NewLeague       0
# ChitsScore      0
# SalaryScore    59
# dtype: int64

# %%
df_salary = df["Salary"]
df_salary.head()
sns.boxplot(x = df_salary);

# %%
Q1 = df_salary.quantile(0.25)
Q1
# Out:
# 176.25

# %%
Q3 = df_salary.quantile(0.75)
Q3
# Out:
# 750.0

# %%
IQR = Q3-Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
print(str(lower)+" "+str(upper))
# Out:
# -684.375 1610.625

# %%
df_salary[(df_salary > upper) | (df_salary < lower)]
# Out:
# 82     1975.000
# 84     1900.000
# 96     1861.460
# 100    2460.000
# 112    1925.571
# 163    2412.500
# 179    1800.000
# 217    2127.333
# 229    1940.000
# 248    1670.000
# Name: Salary, dtype: float64

# %%
df.loc[df["Salary"] > upper,"Salary"] = upper

# %%
df = pd.get_dummies(df, columns = ['League', 'Division', 'NewLeague'], drop_first = True)

# %%
df.shape
# Out:
# (322, 22)

# %%
# We create new variables
catbat=df["CAtBat"]/df["Years"]
chits=df["CHits"]/df["Years"]
chmrun=df["CHmRun"]/df["Years"]
cruns=df["CRuns"]/df["Years"]
crbi=df["CRBI"]/df["Years"]
cwalks=df["CWalks"]/df["Years"]
df_seckin = pd.DataFrame({"ortAtBat":catbat,"ortHits":chits,"ortHmRun":chmrun,"ortRuns":cruns,"ortRBI":crbi,"ortWalks":cwalks})
df = pd.concat([df, df_seckin], axis=1)
df.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  ...  \
# 0    293    66      1    30   29     14      1     293     66       1  ...
# 1    315    81      7    24   38     39     14    3449    835      69  ...
# 2    479   130     18    66   72     76      3    1624    457      63  ...
# 3    496   141     20    65   78     37     11    5628   1575     225  ...
# 4    321    87     10    39   42     30      2     396    101      12  ...
#
#    SalaryScore  League_N  Division_W  NewLeague_N    ortAtBat     ortHits  \
# 0          NaN         0           0            0  293.000000   66.000000
# 1            3         1           1            1  246.357143   59.642857
# 2            3         0           1            0  541.333333  152.333333
# 3            3         1           0            1  511.636364  143.181818
# 4            1         1           0            1  198.000000   50.500000
#
#     ortHmRun    ortRuns     ortRBI   ortWalks
# 0   1.000000  30.000000  29.000000  14.000000
# 1   4.928571  22.928571  29.571429  26.785714
# 2  21.000000  74.666667  88.666667  87.666667
# 3  20.454545  75.272727  76.181818  32.181818
# 4   6.000000  24.000000  23.000000  16.500000
#
# [5 rows x 28 columns]

# %%
df.corr()
# Out:
#                 AtBat      Hits     HmRun      Runs       RBI     Walks  \
# AtBat        1.000000  0.967939  0.592198  0.913060  0.820539  0.669845
# Hits         0.967939  1.000000  0.562158  0.922187  0.811073  0.641211
# HmRun        0.592198  0.562158  1.000000  0.650988  0.855122  0.481014
# Runs         0.913060  0.922187  0.650988  1.000000  0.798206  0.732213
# RBI          0.820539  0.811073  0.855122  0.798206  1.000000  0.615997
# Walks        0.669845  0.641211  0.481014  0.732213  0.615997  1.000000
# Years        0.047372  0.044767  0.116318  0.004541  0.146168  0.136475
# CAtBat       0.235526  0.227565  0.221882  0.186497  0.294688  0.277175
# CHits        0.252717  0.255815  0.220627  0.204830  0.308201  0.280671
# CHmRun       0.236659  0.202712  0.493227  0.227913  0.441771  0.332473
# CRuns        0.266534  0.261787  0.262361  0.250556  0.323285  0.338478
# CRBI         0.244053  0.232005  0.351979  0.205976  0.393184  0.308631
# CWalks       0.166123  0.151818  0.233154  0.182168  0.250914  0.424507
# PutOuts      0.317550  0.310673  0.282923  0.279347  0.343186  0.299515
# Assists      0.353824  0.320455 -0.106329  0.220567  0.106591  0.149656
# Errors       0.352117  0.310038  0.039318  0.240475  0.193370  0.129382
# Salary       0.435226  0.465987  0.360682  0.445570  0.467972  0.469009
# League_N    -0.101663 -0.101038 -0.177258 -0.150392 -0.145597 -0.045337
# Division_W  -0.045441 -0.071143 -0.017206 -0.076311 -0.075531 -0.059086
# NewLeague_N -0.057655 -0.060608 -0.166044 -0.115446 -0.120124 -0.020029
# ortAtBat     0.682601  0.669229  0.417737  0.633326  0.578336  0.521255
# ortHits      0.686120  0.703749  0.411294  0.649075  0.589899  0.517367
# ortHmRun     0.449912  0.414794  0.816323  0.477686  0.703965  0.454593
# ortRuns      0.675838  0.675328  0.466523  0.708969  0.583649  0.594891
# ortRBI       0.605747  0.598846  0.673801  0.580733  0.750534  0.535173
# ortWalks     0.447566  0.429144  0.371388  0.515092  0.432697  0.762129
#
#                 Years    CAtBat     CHits    CHmRun  ...    Salary  League_N  \
# AtBat        0.047372  0.235526  0.252717  0.236659  ...  0.435226 -0.101663
# Hits         0.044767  0.227565  0.255815  0.202712  ...  0.465987 -0.101038
# HmRun        0.116318  0.221882  0.220627  0.493227  ...  0.360682 -0.177258
# Runs         0.004541  0.186497  0.204830  0.227913  ...  0.445570 -0.150392
# RBI          0.146168  0.294688  0.308201  0.441771  ...  0.467972 -0.145597
# Walks        0.136475  0.277175  0.280671  0.332473  ...  0.469009 -0.045337
# Years        1.000000  0.920289  0.903631  0.726872  ...  0.477781 -0.047261
# CAtBat       0.920289  1.000000  0.995063  0.798836  ...  0.589445 -0.028738
# CHits        0.903631  0.995063  1.000000  0.783306  ...  0.607273 -0.025790
# CHmRun       0.726872  0.798836  0.783306  1.000000  ...  0.525003 -0.098383
# CRuns        0.882877  0.983345  0.984609  0.820243  ...  0.617870 -0.054666
# CRBI         0.868812  0.949219  0.945141  0.929484  ...  0.595614 -0.052684
# CWalks       0.838533  0.906501  0.890954  0.799983  ...  0.541719 -0.050884
# PutOuts     -0.004684  0.062283  0.076547  0.112724  ...  0.279486  0.023984
# Assists     -0.080638  0.002038 -0.002523 -0.158511  ...  0.047302  0.045527
# Errors      -0.162140 -0.066922 -0.062756 -0.138115  ...  0.001663  0.078508
# Salary       0.477781  0.589445  0.607273  0.525003  ...  1.000000 -0.025087
# League_N    -0.047261 -0.028738 -0.025790 -0.098383  ... -0.025087  1.000000
# Division_W   0.021126  0.022965  0.013584  0.006783  ... -0.133219 -0.004067
# NewLeague_N -0.042919 -0.016502 -0.010047 -0.097461  ... -0.018355  0.881041
# ortAtBat     0.367124  0.621840  0.629950  0.486955  ...  0.567621 -0.032588
# ortHits      0.382881  0.634487  0.655927  0.484482  ...  0.614603 -0.032725
# ortHmRun     0.264486  0.416974  0.412098  0.731355  ...  0.449703 -0.141052
# ortRuns      0.339320  0.592377  0.608389  0.508524  ...  0.599922 -0.063594
# ortRBI       0.398562  0.610182  0.618941  0.710430  ...  0.608043 -0.095546
# ortWalks     0.363858  0.546807  0.540880  0.521286  ...  0.524560 -0.037832
#
#              Division_W  NewLeague_N  ortAtBat   ortHits  ortHmRun   ortRuns  \
# AtBat         -0.045441    -0.057655  0.682601  0.686120  0.449912  0.675838
# Hits          -0.071143    -0.060608  0.669229  0.703749  0.414794  0.675328
# HmRun         -0.017206    -0.166044  0.417737  0.411294  0.816323  0.466523
# Runs          -0.076311    -0.115446  0.633326  0.649075  0.477686  0.708969
# RBI           -0.075531    -0.120124  0.578336  0.589899  0.703965  0.583649
# Walks         -0.059086    -0.020029  0.521255  0.517367  0.454593  0.594891
# Years          0.021126    -0.042919  0.367124  0.382881  0.264486  0.339320
# CAtBat         0.022965    -0.016502  0.621840  0.634487  0.416974  0.592377
# CHits          0.013584    -0.010047  0.629950  0.655927  0.412098  0.608389
# CHmRun         0.006783    -0.097461  0.486955  0.484482  0.731355  0.508524
# CRuns         -0.000935    -0.042882  0.634104  0.654108  0.459356  0.651350
# CRBI           0.013213    -0.045737  0.581291  0.595989  0.582523  0.566750
# CWalks        -0.005183    -0.051726  0.540616  0.540612  0.443247  0.565722
# PutOuts       -0.005647     0.032833  0.196639  0.216876  0.263075  0.188229
# Assists       -0.013852     0.039066  0.237762  0.208510 -0.163742  0.142253
# Errors        -0.023121     0.050140  0.219225  0.188794 -0.033366  0.132513
# Salary        -0.133219    -0.018355  0.567621  0.614603  0.449703  0.599922
# League_N      -0.004067     0.881041 -0.032588 -0.032725 -0.141052 -0.063594
# Division_W     1.000000    -0.010155  0.008242 -0.011908  0.010274 -0.028306
# NewLeague_N   -0.010155     1.000000 -0.002245  0.000137 -0.145098 -0.042227
# ortAtBat       0.008242    -0.002245  1.000000  0.983534  0.576803  0.949623
# ortHits       -0.011908     0.000137  0.983534  1.000000  0.557464  0.951678
# ortHmRun       0.010274    -0.145098  0.576803  0.557464  1.000000  0.615762
# ortRuns       -0.028306    -0.042227  0.949623  0.951678  0.615762  1.000000
# ortRBI        -0.009664    -0.080232  0.846119  0.847004  0.872095  0.823924
# ortWalks      -0.027449    -0.025131  0.740817  0.719003  0.560331  0.798348
#
#                ortRBI  ortWalks
# AtBat        0.605747  0.447566
# Hits         0.598846  0.429144
# HmRun        0.673801  0.371388
# Runs         0.580733  0.515092
# RBI          0.750534  0.432697
# Walks        0.535173  0.762129
# Years        0.398562  0.363858
# CAtBat       0.610182  0.546807
# CHits        0.618941  0.540880
# CHmRun       0.710430  0.521286
# CRuns        0.630359  0.603505
# CRBI         0.706886  0.545818
# CWalks       0.568592  0.715271
# PutOuts      0.302370  0.198237
# Assists      0.016721  0.059319
# Errors       0.085998  0.024809
# Salary       0.608043  0.524560
# League_N    -0.095546 -0.037832
# Division_W  -0.009664 -0.027449
# NewLeague_N -0.080232 -0.025131
# ortAtBat     0.846119  0.740817
# ortHits      0.847004  0.719003
# ortHmRun     0.872095  0.560331
# ortRuns      0.823924  0.798348
# ortRBI       1.000000  0.705749
# ortWalks     0.705749  1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# # 4. Results after data preprocessing

# %% [markdown]
# ## 4.1.1 Simple linear regression with all data

# %%
from sklearn.linear_model import LinearRegression
X = df[["ortHits"]]
y = df[["Salary"]]
X = scaler.fit_transform(X)
reg_model = LinearRegression()
reg_model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Formula: "+str(reg_model.intercept_)+" "+str(reg_model.coef_)+"x1")
# Out:
# Formula: [508.09903882] [[236.21223579]]x1

# %%
y_pred = reg_model.predict(X)

# %%
from sklearn.metrics import mean_squared_error
sonuc_tum_veri_detay_slr = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_detay_slr
# Out:
# 303.17626852607276

# %%
sonuc_tum_veri_cv_detay_slr = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_detay_slr
# Out:
# 306.9195691112033

# %% [markdown]
# ## 4.1.2 Simple linear regression by separating train and test

# %%
X = df[["ortHits"]]
y = df[["Salary"]]
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Formula: "+str(reg_model.intercept_)+" "+str(reg_model.coef_)+"x1")
# Out:
# Formula: [501.62746841] [[230.22684831]]x1

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_detay_slr = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_detay_slr
# Out:
# 309.94883961016205

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_detay_slr = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_detay_slr
# Out:
# 275.4681670446134

# %%
sonuc_tt_veri_cv_detay_slr = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_detay_slr
# Out:
# 312.7246479727286

# %% [markdown]
# ## 4.2.1 Multiple linear regression with all data

# %%
# We will use these X, y, X_train and y_train in all the remaining modeling.
y = df["Salary"]
X = concatenated_dataframes.drop(['Salary',"SalaryScore","ChitsScore","Assists","Errors","CAtBat","CHits","CHmRun","CRuns","CRBI","CWalks","League_N","NewLeague_N"], axis=1)
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.20, 
                                                    random_state=46)

# %%
reg_model = LinearRegression()
reg_model.fit(X, y)
# Out:
# LinearRegression()

# %%
reg_model.intercept_
# Out:
# 508.09903881987594

# %%
reg_model.coef_
# Out:
# array([ -18.78187555,   28.05635187,   18.56949732,  -18.35152533,
#         -34.47584785,   99.24555048,  112.9523717 ,   42.19076057,
#         -38.56328513, -400.29956824,  370.17962105,  -34.46066441,
#         129.92302147,  128.11627131,  -55.15713266])

# %%
y_pred = reg_model.predict(X)

# %%
sonuc_tum_veri_detay_clr = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_detay_clr
# Out:
# 254.02347315813782

# %%
sonuc_tum_veri_cv_detay_clr = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_detay_clr
# Out:
# 271.7826736061795

# %% [markdown]
# ## 4.2.2 Multiple linear regression by separating train and test

# %%
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg_model.intercept_
# Out:
# 509.6605931396445

# %%
reg_model.coef_
# Out:
# array([ -16.80019679,    8.41271656,    2.39143399,  -29.45060986,
#         -25.16363337,  118.11347023,  125.08843385,   43.93104309,
#         -44.97757109, -414.73582946,  357.80841185,  -46.41131294,
#         173.34260612,  150.59787683,  -84.74533337])

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_detay_clr = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_detay_clr
# Out:
# 255.9966129072163

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_detay_clr = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_detay_clr
# Out:
# 251.4699992494551

# %%
sonuc_tt_veri_cv_detay_clr = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_detay_clr
# Out:
# 274.42826846938954

# %% [markdown]
# ## 4.3.1 Ridge Regression with all data

# %%
reg_model = Ridge()
reg_model.fit(X, y)
# Out:
# Ridge()

# %%
reg_model.intercept_
# Out:
# 508.09903881987594

# %%
reg_model.coef_
# Out:
# array([ -59.12408831,   71.99455624,   16.64054185,  -20.40393139,
#         -31.80524931,  100.67118127,  116.02797524,   44.37908867,
#         -39.1560722 , -300.76424018,  265.7412328 ,  -34.74534313,
#         135.02571141,  127.16936034,  -59.70127583])

# %%
y_pred = reg_model.predict(X)

# %%
sonuc_tum_veri_detay_ridge = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_detay_ridge
# Out:
# 254.33348691822073

# %%
sonuc_tum_veri_cv_detay_ridge = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_detay_ridge
# Out:
# 271.061716245903

# %% [markdown]
# ## 4.3.2 Ridge Regression by separating train and test

# %%
reg_model = Ridge()
reg_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
reg_model.intercept_
# Out:
# 509.4413320301749

# %%
reg_model.coef_
# Out:
# array([ -64.41385392,   58.99433944,   -3.57507804,  -26.57489672,
#         -19.1360011 ,  115.01216715,  128.85073223,   46.51916211,
#         -45.42447704, -297.54584016,  249.41748268,  -35.87218879,
#         163.52143755,  135.35480725,  -82.14882535])

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_detay_ridge = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_detay_ridge
# Out:
# 256.4523112383532

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_detay_ridge = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_detay_ridge
# Out:
# 250.24453184841724

# %%
sonuc_tt_veri_cv_detay_ridge = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_detay_ridge
# Out:
# 272.7165814436063

# %% [markdown]
# ## 4.4.1 Lasso Regression with all data

# %%
reg_model = Lasso()
reg_model.fit(X, y)
# Out:
# Lasso()

# %%
reg_model.intercept_
# Out:
# 508.0990388198759

# %%
reg_model.coef_
# Out:
# array([  -6.55983273,    0.74227425,   -0.        ,    0.        ,
#          -4.63401781,   80.83827572,  113.70940675,   42.8272981 ,
#         -38.60043655, -353.19504022,  379.22064429,   -0.        ,
#          82.72743127,   69.38448835,  -31.32560711])

# %%
y_pred = reg_model.predict(X)

# %%
sonuc_tum_veri_detay_lasso = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_detay_lasso
# Out:
# 254.51053992151796

# %%
sonuc_tum_veri_cv_detay_lasso = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_detay_lasso
# Out:
# 269.6181876059747

# %% [markdown]
# ## 4.4.2 Lasso Regression by separating train and test

# %%
reg_model = Lasso()
reg_model.fit(X_train, y_train)
# Out:
# Lasso()

# %%
reg_model.intercept_
# Out:
# 509.6653180416068

# %%
reg_model.coef_
# Out:
# array([ -22.51321393,    0.        ,  -19.79809736,   -0.        ,
#          -0.        ,   95.37595069,  127.60041363,   45.18030762,
#         -45.02537827, -345.84924621,  355.07067785,   -0.        ,
#         109.94231604,   82.76209055,  -56.22914283])

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_detay_lasso = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_detay_lasso
# Out:
# 256.57771199981516

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_detay_lasso = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_detay_lasso
# Out:
# 248.7365299564664

# %%
sonuc_tt_veri_cv_detay_lasso = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_detay_lasso
# Out:
# 271.61619526027886

# %% [markdown]
# ## 4.5.1 ElasticNet Regression with all data

# %%
reg_model = ElasticNet()
reg_model.fit(X, y)
# Out:
# ElasticNet()

# %%
reg_model.intercept_
# Out:
# 508.09903881987583

# %%
reg_model.coef_
# Out:
# array([ -0.48078134,  21.59844012,  -0.        ,  10.91504259,
#         12.04471341,  29.2433437 ,  81.83697466,  33.5167273 ,
#        -30.1505499 ,  11.77709024,  40.87335853,  10.61612249,
#         32.3775944 ,  35.61369716,  17.75861681])

# %%
y_pred = reg_model.predict(X)

# %%
sonuc_tum_veri_detay_enet = np.sqrt(mean_squared_error(y, y_pred))
sonuc_tum_veri_detay_enet
# Out:
# 270.92444413095683

# %%
sonuc_tum_veri_cv_detay_enet = np.sqrt(np.mean(-cross_val_score(reg_model, X, y, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tum_veri_cv_detay_enet
# Out:
# 279.2396427843337

# %% [markdown]
# ## 4.5.2 ElasticNet Regression by separating train and test

# %%
reg_model = ElasticNet()
reg_model.fit(X_train, y_train)
# Out:
# ElasticNet()

# %%
reg_model.intercept_
# Out:
# 508.56693462949966

# %%
reg_model.coef_
# Out:
# array([ -1.8761461 ,  20.64973176,  -4.31954769,   8.4049047 ,
#         13.10912364,  27.58396235,  88.21781999,  36.07459431,
#        -34.55409259,  11.79083217,  41.58417377,   8.93121572,
#         32.58814165,  35.64135619,  16.63312294])

# %%
y_pred = reg_model.predict(X_train)

# %%
sonuc_train_veri_detay_enet = np.sqrt(mean_squared_error(y_train, y_pred))
sonuc_train_veri_detay_enet
# Out:
# 274.8385083154196

# %%
y_pred = reg_model.predict(X_test)

# %%
sonuc_test_veri_detay_enet = np.sqrt(mean_squared_error(y_test, y_pred))
sonuc_test_veri_detay_enet
# Out:
# 249.51420291442443

# %%
sonuc_tt_veri_cv_detay_enet = np.sqrt(np.mean(-cross_val_score(reg_model, X_train, y_train, cv = 10, scoring = "neg_mean_squared_error")))
sonuc_tt_veri_cv_detay_enet
# Out:
# 281.4344026797186

# %%
# Output of detailed results
detaysonuc_df = pd.DataFrame({"Tüm Veri Score":[sonuc_tum_veri_detay_slr,sonuc_tum_veri_detay_clr,sonuc_tum_veri_detay_ridge,sonuc_tum_veri_detay_lasso,sonuc_tum_veri_detay_enet],
                              "Tüm Veri CVScore":[sonuc_tum_veri_cv_detay_slr,sonuc_tum_veri_cv_detay_clr,sonuc_tum_veri_cv_detay_ridge,sonuc_tum_veri_cv_detay_lasso,sonuc_tum_veri_cv_detay_enet],
                              "Train Veri Sonuc":[sonuc_train_veri_detay_slr,sonuc_train_veri_detay_clr,sonuc_train_veri_detay_ridge,sonuc_train_veri_detay_lasso,sonuc_train_veri_detay_enet],
                              "Test Veri Sonuc":[sonuc_test_veri_detay_slr,sonuc_test_veri_detay_clr,sonuc_test_veri_detay_ridge,sonuc_test_veri_detay_lasso,sonuc_test_veri_detay_enet],                              
                              "TrainTest CVScore":[sonuc_tt_veri_cv_detay_slr,sonuc_tt_veri_cv_detay_clr,sonuc_tt_veri_cv_detay_ridge,sonuc_tt_veri_cv_detay_lasso,sonuc_tt_veri_cv_detay_enet]})
detaysonuc_df.index= ["SLR_DETAY", "CLR_DETAY","RID_DETAY","LAS_DETAY","ENE_DETAY"]
detaysonuc_df
# Out:
#            Tüm Veri Score  Tüm Veri CVScore  Train Veri Sonuc  \
# SLR_DETAY      303.176269        306.919569        309.948840
# CLR_DETAY      254.023473        271.782674        255.996613
# RID_DETAY      254.333487        271.061716        256.452311
# LAS_DETAY      254.510540        269.618188        256.577712
# ENE_DETAY      270.924444        279.239643        274.838508
#
#            Test Veri Sonuc  TrainTest CVScore
# SLR_DETAY       275.468167         312.724648
# CLR_DETAY       251.469999         274.428268
# RID_DETAY       250.244532         272.716581
# LAS_DETAY       248.736530         271.616195
# ENE_DETAY       249.514203         281.434403

# %% [markdown]
# ## 5. CV operations Ridge, Lasso, Enet

# %%
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV

# %% [markdown]
# # 5.1 RidgeCV

# %%
alphas1 = np.random.randint(0,1000,100)
alphas2 = 10**np.linspace(10,-2,100)*0.5
alphas3 = np.linspace(0,1,1000)

# %%
ridge_cv = RidgeCV(alphas = alphas1, scoring = "neg_mean_squared_error", cv = 10, normalize = True)

# %%
ridge_cv.fit(X, y)
# Out:
# RidgeCV(alphas=array([644, 464, 728, 592, 947, 653, 886, 637, 634, 664, 601, 143, 563,
#        152, 151, 793, 403, 311, 259, 292, 173, 966, 754, 904, 566, 440,
#         99, 232, 670, 917, 917, 777, 368, 439, 559, 377,  73, 215, 398,
#        505, 211, 790, 835, 285, 208, 844, 953, 682, 694, 944, 307, 829,
#        591, 886, 193, 749, 703, 612, 278, 546, 814, 950, 539, 159, 524,
#        518, 343, 151, 855, 147, 443, 841, 283, 329, 794, 524, 762, 850,
#        515, 758, 147, 655, 257, 711, 820, 136, 190, 209, 584, 337,  87,
#        278, 374, 109, 261, 394, 200, 252, 602, 474]),
#         cv=10, normalize=True, scoring='neg_mean_squared_error')

# %%
tum_alpha_ridge1 = ridge_cv.alpha_
tum_alpha_ridge1
# Out:
# 73

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([644, 464, 728, 592, 947, 653, 886, 637, 634, 664, 601, 143, 563,
#        152, 151, 793, 403, 311, 259, 292, 173, 966, 754, 904, 566, 440,
#         99, 232, 670, 917, 917, 777, 368, 439, 559, 377,  73, 215, 398,
#        505, 211, 790, 835, 285, 208, 844, 953, 682, 694, 944, 307, 829,
#        591, 886, 193, 749, 703, 612, 278, 546, 814, 950, 539, 159, 524,
#        518, 343, 151, 855, 147, 443, 841, 283, 329, 794, 524, 762, 850,
#        515, 758, 147, 655, 257, 711, 820, 136, 190, 209, 584, 337,  87,
#        278, 374, 109, 261, 394, 200, 252, 602, 474]),
#         cv=10, normalize=True, scoring='neg_mean_squared_error')

# %%
tt_alpha_ridge1 = ridge_cv.alpha_
tt_alpha_ridge1
# Out:
# 73

# %%
ridge_tuned = Ridge(alpha = tum_alpha_ridge1).fit(X, y)
y_pred = ridge_tuned.predict(X)
tum_tuned_ridge1 = np.sqrt(mean_squared_error(y, y_pred))
tum_tuned_ridge1
# Out:
# 265.9920893985055

# %%
ridge_tuned = Ridge(alpha = tt_alpha_ridge1 ).fit(X_train, y_train)
y_pred = ridge_tuned.predict(X_test)
tt_tuned_ridge1 = np.sqrt(mean_squared_error(y_test, y_pred))
tt_tuned_ridge1
# Out:
# 249.24350845303715

# %%
ridge_cv = RidgeCV(alphas = alphas2, scoring = "neg_mean_squared_error", cv = 10, normalize = True)

# %%
ridge_cv.fit(X, y)
# Out:
# RidgeCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         cv=10, normalize=True, scoring='neg_mean_squared_error')

# %%
tum_alpha_ridge2 = ridge_cv.alpha_
tum_alpha_ridge2
# Out:
# 0.008737642000038414

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         cv=10, normalize=True, scoring='neg_mean_squared_error')

# %%
tt_alpha_ridge2 = ridge_cv.alpha_
tt_alpha_ridge2
# Out:
# 0.01155064850041579

# %%
ridge_tuned = Ridge(alpha = tum_alpha_ridge2).fit(X, y)
y_pred = ridge_tuned.predict(X)
tum_tuned_ridge2 = np.sqrt(mean_squared_error(y, y_pred))
tum_tuned_ridge2
# Out:
# 254.02352668374252

# %%
ridge_tuned = Ridge(alpha = tt_alpha_ridge2).fit(X_train, y_train)
y_pred = ridge_tuned.predict(X_test)
tt_tuned_ridge2 = np.sqrt(mean_squared_error(y_test, y_pred))
tt_tuned_ridge2
# Out:
# 251.44592399698246

# %%
ridge_cv = RidgeCV(alphas = alphas3, scoring = "neg_mean_squared_error", cv = 10, normalize = True)

# %%
ridge_cv.fit(X, y)
# Out:
# RidgeCV(alphas=array([0.        , 0.001001  , 0.002002  , 0.003003  , 0.004004  ,
#        0.00500501, 0.00600601, 0.00700701, 0.00800801, 0.00900901,
#        0.01001001, 0.01101101, 0.01201201, 0.01301301, 0.01401401,
#        0.01501502, 0.01601602, 0.01701702, 0.01801802, 0.01901902,
#        0.02002002, 0.02102102, 0.02202202, 0.02302302, 0.02402402,
#        0.02502503, 0.02602603, 0.02702703, 0.02802803, 0.02902903,
#        0.03003003, 0.0...
#        0.97097097, 0.97197197, 0.97297297, 0.97397397, 0.97497497,
#        0.97597598, 0.97697698, 0.97797798, 0.97897898, 0.97997998,
#        0.98098098, 0.98198198, 0.98298298, 0.98398398, 0.98498498,
#        0.98598599, 0.98698699, 0.98798799, 0.98898899, 0.98998999,
#        0.99099099, 0.99199199, 0.99299299, 0.99399399, 0.99499499,
#        0.995996  , 0.996997  , 0.997998  , 0.998999  , 1.        ]),
#         cv=10, normalize=True, scoring='neg_mean_squared_error')

# %%
tum_alpha_ridge3 = ridge_cv.alpha_
tum_alpha_ridge3
# Out:
# 0.008008008008008008

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([0.        , 0.001001  , 0.002002  , 0.003003  , 0.004004  ,
#        0.00500501, 0.00600601, 0.00700701, 0.00800801, 0.00900901,
#        0.01001001, 0.01101101, 0.01201201, 0.01301301, 0.01401401,
#        0.01501502, 0.01601602, 0.01701702, 0.01801802, 0.01901902,
#        0.02002002, 0.02102102, 0.02202202, 0.02302302, 0.02402402,
#        0.02502503, 0.02602603, 0.02702703, 0.02802803, 0.02902903,
#        0.03003003, 0.0...
#        0.97097097, 0.97197197, 0.97297297, 0.97397397, 0.97497497,
#        0.97597598, 0.97697698, 0.97797798, 0.97897898, 0.97997998,
#        0.98098098, 0.98198198, 0.98298298, 0.98398398, 0.98498498,
#        0.98598599, 0.98698699, 0.98798799, 0.98898899, 0.98998999,
#        0.99099099, 0.99199199, 0.99299299, 0.99399399, 0.99499499,
#        0.995996  , 0.996997  , 0.997998  , 0.998999  , 1.        ]),
#         cv=10, normalize=True, scoring='neg_mean_squared_error')

# %%
tt_alpha_ridge3 = ridge_cv.alpha_
tt_alpha_ridge3
# Out:
# 0.011011011011011011

# %%
ridge_tuned = Ridge(alpha = tum_alpha_ridge3).fit(X, y)
y_pred = ridge_tuned.predict(X)
tum_tuned_ridge3 = np.sqrt(mean_squared_error(y, y_pred))
tum_tuned_ridge3
# Out:
# 254.02351815642126

# %%
ridge_tuned = Ridge(alpha = tt_alpha_ridge3).fit(X_train, y_train)
y_pred = ridge_tuned.predict(X_test)
tt_tuned_ridge3 = np.sqrt(mean_squared_error(y_test, y_pred))
tt_tuned_ridge3
# Out:
# 251.4470398524765

# %%
if (tum_tuned_ridge1 < tum_tuned_ridge2) & (tum_tuned_ridge1 < tum_tuned_ridge3):
    tum_tuned_ridge = tum_tuned_ridge1
    tum_alpha_ridge = tum_alpha_ridge1
elif tum_tuned_ridge2 < tum_tuned_ridge3:
    tum_tuned_ridge = tum_tuned_ridge2
    tum_alpha_ridge = tum_alpha_ridge2
else:
    tum_tuned_ridge = tum_tuned_ridge3
    tum_alpha_ridge = tum_alpha_ridge3
print("RMSE:"+str(tum_tuned_ridge)+"  Alpha:"+str(tum_alpha_ridge))
# Out:
# RMSE:254.02351815642126  Alpha:0.008008008008008008

# %%
if (tt_tuned_ridge1 < tt_tuned_ridge2) & (tt_tuned_ridge1 < tt_tuned_ridge3):
    tt_tuned_ridge = tt_tuned_ridge1
    tt_alpha_ridge = tt_alpha_ridge1
elif tum_tuned_ridge2 < tum_tuned_ridge3:
    tt_tuned_ridge = tt_tuned_ridge2
    tt_alpha_ridge = tt_alpha_ridge2
else:
    tt_tuned_ridge = tt_tuned_ridge3
    tt_alpha_ridge = tt_alpha_ridge3
print("RMSE:"+str(tt_tuned_ridge)+"  Alpha:"+str(tt_alpha_ridge))
# Out:
# RMSE:249.24350845303715  Alpha:73

# %% [markdown]
# # 5.2 LassoCv

# %%
alphas1 = np.random.randint(0,1000,100)
alphas2 = 10**np.linspace(10,-2,100)*0.5
alphas3 = np.linspace(0,1,1000)

# %%
lasso_cv = LassoCV(alphas = alphas1, cv = 10)

# %%
lasso_cv.fit(X, y)
# Out:
# LassoCV(alphas=array([666, 745, 266, 352, 161, 236,  65, 888,  62,  23, 148, 997, 276,
#        829, 483, 394,  99, 984, 564,  57, 556,  55, 218, 272, 289, 853,
#        232, 364, 747, 578, 358, 864, 863, 147, 453, 897,  18, 904, 175,
#        657, 451, 145, 927, 211, 568, 518, 854, 545, 785, 753, 937, 766,
#        993, 864, 882, 912, 700, 382, 976, 768, 497, 344, 632, 141, 238,
#        733, 563, 860, 751, 185,  58, 576, 905, 595, 113, 474, 106, 226,
#        865, 532, 620, 816, 745, 380, 248, 313, 300,  49, 529,  94,  37,
#        982, 500, 929, 996, 269,  52,  44, 333, 613]),
#         cv=10)

# %%
tum_alpha_lasso1 = lasso_cv.alpha_
tum_alpha_lasso1
# Out:
# 18

# %%
lasso_cv.fit(X_train, y_train)
# Out:
# LassoCV(alphas=array([666, 745, 266, 352, 161, 236,  65, 888,  62,  23, 148, 997, 276,
#        829, 483, 394,  99, 984, 564,  57, 556,  55, 218, 272, 289, 853,
#        232, 364, 747, 578, 358, 864, 863, 147, 453, 897,  18, 904, 175,
#        657, 451, 145, 927, 211, 568, 518, 854, 545, 785, 753, 937, 766,
#        993, 864, 882, 912, 700, 382, 976, 768, 497, 344, 632, 141, 238,
#        733, 563, 860, 751, 185,  58, 576, 905, 595, 113, 474, 106, 226,
#        865, 532, 620, 816, 745, 380, 248, 313, 300,  49, 529,  94,  37,
#        982, 500, 929, 996, 269,  52,  44, 333, 613]),
#         cv=10)

# %%
tt_alpha_lasso1 = lasso_cv.alpha_
tt_alpha_lasso1
# Out:
# 18

# %%
lasso_tuned = Lasso(alpha = tum_alpha_lasso1).fit(X, y)
y_pred = lasso_tuned.predict(X)
tum_tuned_lasso1 = np.sqrt(mean_squared_error(y, y_pred))
tum_tuned_lasso1
# Out:
# 267.0320607829059

# %%
lasso_tuned = Lasso(alpha = tt_alpha_lasso1).fit(X_train, y_train)
y_pred = lasso_tuned.predict(X_test)
tt_tuned_lasso1 = np.sqrt(mean_squared_error(y_test, y_pred))
tt_tuned_lasso1
# Out:
# 251.9854274896165

# %%
lasso_cv = LassoCV(alphas = alphas2, cv = 10)

# %%
lasso_cv.fit(X, y)
# Out:
# LassoCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        3.06795364e+00, 2.32079442e+00, 1.75559587e+00, 1.32804389e+00,
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         cv=10)

# %%
tum_alpha_lasso2 = lasso_cv.alpha_
tum_alpha_lasso2
# Out:
# 1.7555958671075638

# %%
lasso_cv.fit(X_train, y_train)
# Out:
# LassoCV(alphas=array([5.00000000e+09, 3.78231664e+09, 2.86118383e+09, 2.16438064e+09,
#        1.63727458e+09, 1.23853818e+09, 9.36908711e+08, 7.08737081e+08,
#        5.36133611e+08, 4.05565415e+08, 3.06795364e+08, 2.32079442e+08,
#        1.75559587e+08, 1.32804389e+08, 1.00461650e+08, 7.59955541e+07,
#        5.74878498e+07, 4.34874501e+07, 3.28966612e+07, 2.48851178e+07,
#        1.88246790e+07, 1.42401793e+0...
#        3.06795364e+00, 2.32079442e+00, 1.75559587e+00, 1.32804389e+00,
#        1.00461650e+00, 7.59955541e-01, 5.74878498e-01, 4.34874501e-01,
#        3.28966612e-01, 2.48851178e-01, 1.88246790e-01, 1.42401793e-01,
#        1.07721735e-01, 8.14875417e-02, 6.16423370e-02, 4.66301673e-02,
#        3.52740116e-02, 2.66834962e-02, 2.01850863e-02, 1.52692775e-02,
#        1.15506485e-02, 8.73764200e-03, 6.60970574e-03, 5.00000000e-03]),
#         cv=10)

# %%
tt_alpha_lasso2 = lasso_cv.alpha_
tt_alpha_lasso2
# Out:
# 1.7555958671075638

# %%
lasso_tuned = Lasso(alpha = tum_alpha_lasso2).fit(X, y)
y_pred = lasso_tuned.predict(X)
tum_tuned_lasso2 = np.sqrt(mean_squared_error(y, y_pred))
tum_tuned_lasso2
# Out:
# 255.2144742986989

# %%
lasso_tuned = Lasso(alpha = tt_alpha_lasso2).fit(X_train, y_train)
y_pred = lasso_tuned.predict(X_test)
tt_tuned_lasso2 = np.sqrt(mean_squared_error(y_test, y_pred))
tt_tuned_lasso2
# Out:
# 247.65813703196073

# %%
lasso_cv = LassoCV(alphas = alphas3, cv = 10)

# %%
lasso_cv.fit(X, y)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9629695.63731531, tolerance: 4444.735581754667
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9804167.839021422, tolerance: 4358.022814932946
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9195590.193602078, tolerance: 4090.854780028226
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9457038.027280401, tolerance: 4199.837617681543
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9372114.767026503, tolerance: 4371.351360043242
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9469925.037848558, tolerance: 4066.17511535985
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8691907.78631945, tolerance: 4359.173103125896
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8807649.29357598, tolerance: 4274.230092350763
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9504858.232373409, tolerance: 4328.881862180241
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8897225.770926349, tolerance: 4291.755736636081
#   tol, rng, random, positive)
# LassoCV(alphas=array([0.        , 0.001001  , 0.002002  , 0.003003  , 0.004004  ,
#        0.00500501, 0.00600601, 0.00700701, 0.00800801, 0.00900901,
#        0.01001001, 0.01101101, 0.01201201, 0.01301301, 0.01401401,
#        0.01501502, 0.01601602, 0.01701702, 0.01801802, 0.01901902,
#        0.02002002, 0.02102102, 0.02202202, 0.02302302, 0.02402402,
#        0.02502503, 0.02602603, 0.02702703, 0.02802803, 0.02902903,
#        0.03003003, 0.0...
#        0.96596597, 0.96696697, 0.96796797, 0.96896897, 0.96996997,
#        0.97097097, 0.97197197, 0.97297297, 0.97397397, 0.97497497,
#        0.97597598, 0.97697698, 0.97797798, 0.97897898, 0.97997998,
#        0.98098098, 0.98198198, 0.98298298, 0.98398398, 0.98498498,
#        0.98598599, 0.98698699, 0.98798799, 0.98898899, 0.98998999,
#        0.99099099, 0.99199199, 0.99299299, 0.99399399, 0.99499499,
#        0.995996  , 0.996997  , 0.997998  , 0.998999  , 1.        ]),
#         cv=10)

# %%
tum_alpha_lasso3 = lasso_cv.alpha_
tum_alpha_lasso3
# Out:
# 1.0

# %%
lasso_cv.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7582070.840701707, tolerance: 3528.373092893085
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7296236.308830779, tolerance: 3404.6934652610753
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7726938.893643916, tolerance: 3565.6459305087255
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7929873.923237029, tolerance: 3542.887576369448
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7768571.288365636, tolerance: 3426.1623522014493
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7973571.091260437, tolerance: 3579.3854131174
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6406517.143246248, tolerance: 3506.791565554989
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7216611.021297559, tolerance: 3279.568215558199
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7842271.438098758, tolerance: 3637.253387993311
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   tol, rng, random, positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7492143.7084811255, tolerance: 3504.114609610751
#   tol, rng, random, positive)
# LassoCV(alphas=array([0.        , 0.001001  , 0.002002  , 0.003003  , 0.004004  ,
#        0.00500501, 0.00600601, 0.00700701, 0.00800801, 0.00900901,
#        0.01001001, 0.01101101, 0.01201201, 0.01301301, 0.01401401,
#        0.01501502, 0.01601602, 0.01701702, 0.01801802, 0.01901902,
#        0.02002002, 0.02102102, 0.02202202, 0.02302302, 0.02402402,
#        0.02502503, 0.02602603, 0.02702703, 0.02802803, 0.02902903,
#        0.03003003, 0.0...
#        0.96596597, 0.96696697, 0.96796797, 0.96896897, 0.96996997,
#        0.97097097, 0.97197197, 0.97297297, 0.97397397, 0.97497497,
#        0.97597598, 0.97697698, 0.97797798, 0.97897898, 0.97997998,
#        0.98098098, 0.98198198, 0.98298298, 0.98398398, 0.98498498,
#        0.98598599, 0.98698699, 0.98798799, 0.98898899, 0.98998999,
#        0.99099099, 0.99199199, 0.99299299, 0.99399399, 0.99499499,
#        0.995996  , 0.996997  , 0.997998  , 0.998999  , 1.        ]),
#         cv=10)

# %%
tt_alpha_lasso3 = lasso_cv.alpha_
tt_alpha_lasso3
# Out:
# 0.991991991991992

# %%
lasso_tuned = Lasso(alpha = tt_alpha_lasso3).fit(X, y)
y_pred = lasso_tuned.predict(X)
tum_tuned_lasso3 = np.sqrt(mean_squared_error(y, y_pred))
tum_tuned_lasso3
# Out:
# 254.5044628714397

# %%
lasso_tuned = Lasso(alpha = tt_alpha_lasso3).fit(X_train, y_train)
y_pred = lasso_tuned.predict(X_test)
tt_tuned_lasso3 = np.sqrt(mean_squared_error(y_test, y_pred))
tt_tuned_lasso3
# Out:
# 248.7507013329124

# %%
if (tum_tuned_lasso1 < tum_tuned_lasso2) & (tum_tuned_lasso1 < tum_tuned_lasso3):
    tum_tuned_lasso = tum_tuned_lasso1
    tum_alpha_lasso = tum_alpha_lasso1
elif tum_tuned_lasso2 < tum_tuned_lasso3:
    tum_tuned_lasso = tum_tuned_lasso2
    tum_alpha_lasso = tum_alpha_lasso2
else:
    tum_tuned_lasso = tum_tuned_lasso3
    tum_alpha_lasso = tum_alpha_lasso3
print("RMSE:"+str(tum_tuned_lasso)+"  Alpha:"+str(tum_alpha_lasso))
# Out:
# RMSE:254.5044628714397  Alpha:1.0

# %%
if (tt_tuned_lasso1 < tt_tuned_lasso2) & (tt_tuned_lasso1 < tt_tuned_lasso3):
    tt_tuned_lasso = tt_tuned_lasso1
    tt_alpha_lasso = tt_alpha_lasso1
elif tt_tuned_lasso2 < tt_tuned_lasso3:
    tt_tuned_lasso = tt_tuned_lasso2
    tt_alpha_lasso = tt_alpha_lasso2
else:
    tt_tuned_lasso = tt_tuned_lasso3
    tt_alpha_lasso = tt_alpha_lasso3
print("RMSE:"+str(tt_tuned_lasso)+"  Alpha:"+str(tt_alpha_lasso))
# Out:
# RMSE:247.65813703196073  Alpha:1.7555958671075638

# %% [markdown]
# # 5.3 EnetCV

# %%
from sklearn.model_selection import GridSearchCV
enet_params = {"l1_ratio": [0.1,0.2,0.4,0.5,0.6,0.8,1],
              "alpha":[0.1,0.01,0.001,0.2,0.3,0.5,0.8,0.9,1]}
enet_model = ElasticNet()

# %%
gs_cv_enet = GridSearchCV(enet_model, enet_params, cv = 10).fit(X, y)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40842.02965027094, tolerance: 4444.735581754667
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11529.41949954629, tolerance: 4371.351360043242
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5839.192382480949, tolerance: 4359.173103125896
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77897.65188683942, tolerance: 4274.230092350763
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39893.81859347597, tolerance: 4328.881862180241
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27907.04328601435, tolerance: 4291.755736636081
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20326.137221764773, tolerance: 4444.735581754667
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40392.012991962954, tolerance: 4274.230092350763
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16455.133639857173, tolerance: 4328.881862180241
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11123.412253204733, tolerance: 4291.755736636081
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17585.935187716037, tolerance: 4444.735581754667
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37625.961059615016, tolerance: 4274.230092350763
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10061.445848412812, tolerance: 4328.881862180241
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6222.878725323826, tolerance: 4291.755736636081
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21148.64235748723, tolerance: 4444.735581754667
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45019.36718009226, tolerance: 4274.230092350763
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9837.337221741676, tolerance: 4328.881862180241
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26850.381716210395, tolerance: 4444.735581754667
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52529.501215942204, tolerance: 4274.230092350763
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10304.534110438079, tolerance: 4328.881862180241
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48399.44423298165, tolerance: 4444.735581754667
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102855.89479392208, tolerance: 4274.230092350763
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12702.787090234458, tolerance: 4328.881862180241
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 94005.19343226776, tolerance: 4444.735581754667
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6853.855465110391, tolerance: 4090.854780028226
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5587.927771363407, tolerance: 4066.17511535985
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 189569.3738395609, tolerance: 4274.230092350763
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16897.819867536426, tolerance: 4328.881862180241
#   positive)

# %%
gs_cv_enet.best_params_
# Out:
# {'alpha': 1, 'l1_ratio': 1}

# %%
tum_tuned_enet_a = gs_cv_enet.best_params_["alpha"]
tum_tuned_enet_a
# Out:
# 1

# %%
tum_tuned_enet_l = gs_cv_enet.best_params_["l1_ratio"]
tum_tuned_enet_l
# Out:
# 1

# %%
enet_tuned = ElasticNet(**gs_cv_enet.best_params_).fit(X, y)
y_pred = enet_tuned.predict(X)
tum_tuned_enet = np.sqrt(mean_squared_error(y, y_pred))
tum_tuned_enet
# Out:
# 254.51053992151796

# %%
gs_cv_enet = GridSearchCV(enet_model, enet_params, cv = 10).fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31687.079969191924, tolerance: 3404.6934652610753
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32705.100254915655, tolerance: 3426.1623522014493
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16398.047160722315, tolerance: 3579.3854131174
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47378.10004988313, tolerance: 3279.568215558199
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5448.947162911296, tolerance: 3637.253387993311
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4194.438225409016, tolerance: 3504.114609610751
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13004.400147778913, tolerance: 3404.6934652610753
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14140.093652933836, tolerance: 3426.1623522014493
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6484.796612750739, tolerance: 3579.3854131174
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22685.349739430472, tolerance: 3279.568215558199
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7795.131543887779, tolerance: 3404.6934652610753
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9536.232249794528, tolerance: 3426.1623522014493
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3685.7001627553254, tolerance: 3579.3854131174
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18494.962707895786, tolerance: 3279.568215558199
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7460.5983295589685, tolerance: 3404.6934652610753
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9804.718031343073, tolerance: 3426.1623522014493
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21049.86298111826, tolerance: 3279.568215558199
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7517.210805395618, tolerance: 3404.6934652610753
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10811.078069100156, tolerance: 3426.1623522014493
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25716.454151105136, tolerance: 3279.568215558199
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14822.912840213627, tolerance: 3426.1623522014493
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3781.849903697148, tolerance: 3579.3854131174
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43403.54560199194, tolerance: 3279.568215558199
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7084.722334608436, tolerance: 3528.373092893085
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8551.818830266595, tolerance: 3565.6459305087255
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22104.9807037618, tolerance: 3426.1623522014493
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4267.946345232427, tolerance: 3579.3854131174
#   positive)
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:531: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79725.60868247226, tolerance: 3279.568215558199
#   positive)

# %%
gs_cv_enet.best_params_
# Out:
# {'alpha': 1, 'l1_ratio': 1}

# %%
tt_tuned_enet_a = gs_cv_enet.best_params_["alpha"]
tt_tuned_enet_a
# Out:
# 1

# %%
tt_tuned_enet_l = gs_cv_enet.best_params_["l1_ratio"]
tt_tuned_enet_l
# Out:
# 1

# %%
enet_tuned = ElasticNet(**gs_cv_enet.best_params_).fit(X_train, y_train)
y_pred = enet_tuned.predict(X_test)
tt_tuned_enet = np.sqrt(mean_squared_error(y_test, y_pred))
tt_tuned_enet
# Out:
# 248.7365299564664

# %%
# Output of detailed results
detaysonuc_df = pd.DataFrame({"All Data Error":[sonuc_tum_veri_detay_slr,sonuc_tum_veri_detay_clr,sonuc_tum_veri_detay_ridge,sonuc_tum_veri_detay_lasso,sonuc_tum_veri_detay_enet],
                              "All Data cvScore(K-Fold)":[sonuc_tum_veri_cv_detay_slr,sonuc_tum_veri_cv_detay_clr,sonuc_tum_veri_cv_detay_ridge,sonuc_tum_veri_cv_detay_lasso,sonuc_tum_veri_cv_detay_enet],
                              "All Data Tuned Error":[0,0,tum_tuned_ridge,tum_tuned_lasso,tum_tuned_enet],
                              "Train Error":[sonuc_train_veri_detay_slr,sonuc_train_veri_detay_clr,sonuc_train_veri_detay_ridge,sonuc_train_veri_detay_lasso,sonuc_train_veri_detay_enet],
                              "Test Error":[sonuc_test_veri_detay_slr,sonuc_test_veri_detay_clr,sonuc_test_veri_detay_ridge,sonuc_test_veri_detay_lasso,sonuc_test_veri_detay_enet],                              
                              "Train cvScore(K-Fold)":[sonuc_tt_veri_cv_detay_slr,sonuc_tt_veri_cv_detay_clr,sonuc_tt_veri_cv_detay_ridge,sonuc_tt_veri_cv_detay_lasso,sonuc_tt_veri_cv_detay_enet],
                              "Test Tuned Error":[0,0,tt_tuned_ridge,tt_tuned_lasso,tt_tuned_enet]})
detaysonuc_df.index= ["SLR_DETAY", "CLR_DETAY","RID_DETAY","LAS_DETAY","ENE_DETAY"]

# %%
detaysonuc_df
# Out:
#            All Data Error  All Data cvScore(K-Fold)  All Data Tuned Error  \
# SLR_DETAY      303.176269                306.919569              0.000000
# CLR_DETAY      254.023473                271.782674              0.000000
# RID_DETAY      254.333487                271.061716            254.023518
# LAS_DETAY      254.510540                269.618188            254.504463
# ENE_DETAY      270.924444                279.239643            254.510540
#
#            Train Error  Test Error  Train cvScore(K-Fold)  Test Tuned Error
# SLR_DETAY   309.948840  275.468167             312.724648          0.000000
# CLR_DETAY   255.996613  251.469999             274.428268          0.000000
# RID_DETAY   256.452311  250.244532             272.716581        249.243508
# LAS_DETAY   256.577712  248.736530             271.616195        247.658137
# ENE_DETAY   274.838508  249.514203             281.434403        248.736530

# %%
basicsonuc_df
# Out:
#      All Data Error  All Data cvScore(K-Fold)  Train Error  Test Error  \
# SLR      376.364303                383.452652   348.967844  472.230050
# CLR      303.344473                341.465977   261.361519  479.071504
# RID      304.114038                338.453184   264.576760  458.751443
# LAS      304.317294                338.626547   263.705645  461.242286
# ENE      326.562196                343.059463   285.633356  463.935294
#
#      Train cvScore(K-Fold)
# SLR             352.695909
# CLR             307.225761
# RID             301.308450
# LAS             301.120525
# ENE             299.848428
